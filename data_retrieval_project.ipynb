# %%
import requests as r, json

# Step 1: make the request

# GitHub API endpoint for repository information
url = 'https://hp-api.onrender.com/api/characters'
res = r.get(url)
res.text
# Out:
# '[{"id":"9e3f7ce4-b9a7-4244-b709-dae5c1f1d4a8","name":"Harry Potter","alternate_names":["The Boy Who Lived","The Chosen One","Undesirable No. 1","Potty"],"species":"human","gender":"male","house":"Gryffindor","dateOfBirth":"31-07-1980","yearOfBirth":1980,"wizard":true,"ancestry":"half-blood","eyeColour":"green","hairColour":"black","wand":{"wood":"holly","core":"phoenix tail feather","length":11},"patronus":"stag","hogwartsStudent":true,"hogwartsStaff":false,"actor":"Daniel Radcliffe","alternate_actors":[],"alive":true,"image":"https://ik.imagekit.io/hpapi/harry.jpg"},{"id":"4c7e6819-a91a-45b2-a454-f931e4a7cce3","name":"Hermione Granger","alternate_names":["Hermy","Know-it-all","Miss Grant","Herm-own-ninny"],"species":"human","gender":"female","house":"Gryffindor","dateOfBirth":"19-09-1979","yearOfBirth":1979,"wizard":true,"ancestry":"muggleborn","eyeColour":"brown","hairColour":"brown","wand":{"wood":"vine","core":"dragon heartstring","length":10.75},"patronus":"otter","hogwartsStud
# ...

# %%
# Step 2: convert results to json
res_json = json.loads(res.text)
res_json
# Out:
# [{'id': '9e3f7ce4-b9a7-4244-b709-dae5c1f1d4a8',
#   'name': 'Harry Potter',
#   'alternate_names': ['The Boy Who Lived',
#    'The Chosen One',
#    'Undesirable No. 1',
#    'Potty'],
#   'species': 'human',
#   'gender': 'male',
#   'house': 'Gryffindor',
#   'dateOfBirth': '31-07-1980',
#   'yearOfBirth': 1980,
#   'wizard': True,
#   'ancestry': 'half-blood',
#   'eyeColour': 'green',
#   'hairColour': 'black',
#   'wand': {'wood': 'holly', 'core': 'phoenix tail feather', 'length': 11},
#   'patronus': 'stag',
#   'hogwartsStudent': True,
#   'hogwartsStaff': False,
#   'actor': 'Daniel Radcliffe',
#   'alternate_actors': [],
#   'alive': True,
#   'image': 'https://ik.imagekit.io/hpapi/harry.jpg'},
#  {'id': '4c7e6819-a91a-45b2-a454-f931e4a7cce3',
#   'name': 'Hermione Granger',
#   'alternate_names': ['Hermy', 'Know-it-all', 'Miss Grant', 'Herm-own-ninny'],
#   'species': 'human',
#   'gender': 'female',
#   'house': 'Gryffindor',
#   'dateOfBirth': '19-09-1979',
# ...

# %%
import pandas as pd

# Step 3: Drill down to the data you want
data = res_json

# Step 4: Convert data back to str of json which prepares it to be converted to a DataFrame
data = json.dumps(data)
type(data)
# Out:
# str

# %%
df = pd.read_json(data)
df.head()
# Out:
# /var/folders/n0/fpj669xs7mdf7dy6vwdnptk40000gn/T/ipykernel_38652/3751206123.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(data)
#                                      id                name  \
# 0  9e3f7ce4-b9a7-4244-b709-dae5c1f1d4a8        Harry Potter
# 1  4c7e6819-a91a-45b2-a454-f931e4a7cce3    Hermione Granger
# 2  c3b1f9a5-b87b-48bf-b00d-95b093ea6390         Ron Weasley
# 3  af95bd8a-dfae-45bb-bc69-533860d34129        Draco Malfoy
# 4  ca3827f0-375a-4891-aaa5-f5e8a5bad225  Minerva McGonagall
#
#                                      alternate_names species  gender  \
# 0  [The Boy Who Lived, The Chosen One, Undesirabl...   human    male
# 1   [Hermy, Know-it-all, Miss Grant, Herm-own-ninny]   human  female
# 2  [Dragomir Despard, Ronald, Ickle Ronniekins, R...   human    male
# ...

# %%
df.shape[0]
# Out:
# 404

# %%
df.fillna('n/a', inplace=True)
df.head(10)
# Out:
# /var/folders/n0/fpj669xs7mdf7dy6vwdnptk40000gn/T/ipykernel_38652/1196239163.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'n/a' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('n/a', inplace=True)
#                                      id                name  \
# 0  9e3f7ce4-b9a7-4244-b709-dae5c1f1d4a8        Harry Potter
# 1  4c7e6819-a91a-45b2-a454-f931e4a7cce3    Hermione Granger
# 2  c3b1f9a5-b87b-48bf-b00d-95b093ea6390         Ron Weasley
# 3  af95bd8a-dfae-45bb-bc69-533860d34129        Draco Malfoy
# 4  ca3827f0-375a-4891-aaa5-f5e8a5bad225  Minerva McGonagall
# 5  d5c4daa3-c726-426a-aa98-fb40f3fba816      Cedric Diggory
# 6  8f9aa40b-5d7c-441e-ad32-4564ecda3b70           Cho Chang
# 7  3569d265-bd27-44d8-88e8-82fb0a848374       Severus Snape
# 8  36bfefd0-e0bb-4d11-be98-d1ef6117a77a       Rubeus Hagrid
# ...
