# %%
import pandas as pd 

df = pd.read_csv('housing.csv')
pd.set_option('display.max_columns', None)
print(df.shape)
df.head()
# Out:
# (2919, 80)
#    SalePrice  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   208500.0          60       RL         65.0     8450   Pave   NaN      Reg
# 1   181500.0          20       RL         80.0     9600   Pave   NaN      Reg
# 2   223500.0          60       RL         68.0    11250   Pave   NaN      IR1
# 3   140000.0          70       RL         60.0     9550   Pave   NaN      IR1
# 4   250000.0          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
import sys
sys.path.append('functions.py')
import functions as fun
# from functions import basic_wrangling

fun.basic_wrangling(df)
# Out:
# Column Alley dropped because of too much missing data (93.0%)
# Column MasVnrType dropped because of too much missing data (61.0%)
# Column PoolQC dropped because of too much missing data (100.0%)
# Column Fence dropped because of too much missing data (80.0%)
# Column MiscFeature dropped because of too much missing data (96.0%)
#    SalePrice  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0   208500.0          60       RL         65.0     8450   Pave      Reg
# 1   181500.0          20       RL         80.0     9600   Pave      Reg
# 2   223500.0          60       RL         68.0    11250   Pave      IR1
# 3   140000.0          70       RL         60.0     9550   Pave      IR1
# 4   250000.0          60       RL         84.0    14260   Pave      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# ...

# %%
# perform EDA inculding univariate and bivariate stats and visualizations

# %%
# address missing data
print(df.shape)
df.drop(columns=['FireplaceQu'], inplace=True) #drop columns that weren't already dropped for too much
df.dropna(inplace=True)
print(df.shape)
df.isna().sum()
# Out:
# (2919, 75)
# (1094, 74)
# SalePrice        0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 74, dtype: int64

# %%
# detect and address outliers
# skip for now, but you can build a cluster model

# %%
# bin lowcount categorical groups

# %%
# correct skewness

# %%
# dummy coding

# %%
# set up the model including y and X
# train/fit the model
import statsmodels.api as sm

y = df['SalePrice']
X = df.select_dtypes('number').assign(const=1).drop(columns=['SalePrice'])
    # this const is dumb and we don't love using statsmodels.api, but it's one way to do it.
    # it adds a column where everything is 1
model = sm.OLS(y,X).fit()
print(model.summary())
df.head()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.802
# Method:                 Least Squares   F-statistic:                     130.9
# Date:                Thu, 08 Feb 2024   Prob (F-statistic):               0.00
# Time:                        15:10:03   Log-Likelihood:                -13043.
# No. Observations:                1094   AIC:                         2.616e+04
# Df Residuals:                    1059   BIC:                         2.633e+04
# Df Model:                          34
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# MSSubClass     -194.0845     35.235     -5.508      0.000    -263.223    -124.946
# ...

# %%
# VIF
fun.vif(X.drop(columns=['const']))
# Out:
# /Users/graceogden/Documents/BYU/2024 1-Winter/IS455/ClassCode455/functions.py:78: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1 / (1 - r_squared) # VIF = 3 is the cutoff
# /Users/graceogden/Documents/BYU/2024 1-Winter/IS455/ClassCode455/functions.py:78: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1 / (1 - r_squared) # VIF = 3 is the cutoff
# /Users/graceogden/Documents/BYU/2024 1-Winter/IS455/ClassCode455/functions.py:78: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1 / (1 - r_squared) # VIF = 3 is the cutoff
# /Users/graceogden/Documents/BYU/2024 1-Winter/IS455/ClassCode455/functions.py:78: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1 / (1 - r_squared) # VIF = 3 is the cutoff
# /Users/graceogden/Documents/BYU/2024 1-Winter/IS455/ClassCode455/functions.py:78: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1 / (1 - r_squared) # VIF = 3 is the cutoff
# ...

# %%
# view results
